# %%
from docling.document_converter import DocumentConverter
converter = DocumentConverter()
result = converter.convert("https://www.fh-swf.de/de/studienangebot/fachbereiche_3/test_5.php")
md_content = result.document.export_to_markdown()
html_content = result.document.export_to_html()
text_content = result.document.export_to_text()

# %% [markdown]
# Unterschiede in den Exportformaten prüfen:

# %%
print(md_content)
# Out:
# - Jetzt bewerben!
# - Merken &amp; Infos
# - Login
# - International
#
# <!-- image -->
#
# - Zurück
# - Studieninteressierte Studieninteressierte Studieninteressierte
#     - Zurück
#     - Studieninteressierte
#     - Information &amp; Beratung
#         - Zurück
#         - Information &amp; Beratung
#         - Allgemeine Studienberatung
#         - Talentscouting
#         - Info-Veranstaltungen
#         - Warum bei uns studieren?
#         - Studieren ohne Abitur
#         - Wir erklären die Hochschulwelt
#         - Studium von A-Z
# - Bewerbung &amp; Einschreibung
#     - Zurück
#     - Bewerbung &amp; Einschreibung
#     - Bewerbung für ein Bachelorstudium
#     - Bewerbung für ein Masterstudium
#     - Bewerbung für Gasthörer/Quereinsteiger/Zweithörer
#     - Bewerbung für ein Promotionsstudium
#     - Bewerbungsfristen
#     - Beiträge und Gebühren
# - Studienvorbereitung
#
# - Zurück
# - Studienvorbereitung
# - Finanzielles
# - Wohnen
# - Studienstart
# ...

# %%
print(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="icon" type="image/png"
#     href="https://ds4sd.github.io/docling/assets/logo.png"/>
#     <meta charset="UTF-8">
#     <title>
#     Powered by Docling
#     </title>
#     <style>
#     html {
#     background-color: LightGray;
#     }
#     body {
#     margin: 0 auto;
#     width:800px;
#     padding: 30px;
#     background-color: White;
#     font-family: Arial, sans-serif;
#     box-shadow: 10px 10px 10px grey;
#     }
#     figure{
#     display: block;
#     width: 100%;
#     margin: 0px;
#     margin-top: 10px;
#     margin-bottom: 10px;
#     }
#     img {
#     display: block;
#     margin: auto;
#     margin-top: 10px;
#     margin-bottom: 10px;
#     max-width: 640px;
#     max-height: 640px;
#     }
#     table {
#     min-width:500px;
#     background-color: White;
#     border-collapse: collapse;
#     cell-padding: 5px;
#     margin: auto;
#     margin-top: 10px;
#     margin-bottom: 10px;
#     }
# ...

# %%
print(text_content)
# Out:
# Jetzt bewerben!
#
#  Merken &amp; Infos
#
#  Login
#
#  International
#
# <!-- missing-text -->
#
#  Zurück
#
#  Studieninteressierte Studieninteressierte Studieninteressierte
#
#      Zurück
#
#      Studieninteressierte
#
#      Information &amp; Beratung
#
#          Zurück
#
#          Information &amp; Beratung
#
#          Allgemeine Studienberatung
#
#          Talentscouting
#
#          Info-Veranstaltungen
#
#          Warum bei uns studieren?
#
#          Studieren ohne Abitur
#
#          Wir erklären die Hochschulwelt
#
#          Studium von A-Z
#
#  Bewerbung &amp; Einschreibung
#
#      Zurück
#
#      Bewerbung &amp; Einschreibung
#
#      Bewerbung für ein Bachelorstudium
#
#      Bewerbung für ein Masterstudium
#
#      Bewerbung für Gasthörer/Quereinsteiger/Zweithörer
#
#      Bewerbung für ein Promotionsstudium
#
#      Bewerbungsfristen
#
#      Beiträge und Gebühren
#
#  Studienvorbereitung
#
#  Zurück
#
#  Studienvorbereitung
#
#  Finanzielles
#
#  Wohnen
#
# ...

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions

# %%
pdf_options = PdfPipelineOptions(do_ocr=False, do_table_structure=True)
converter = DocumentConverter(
    allowed_formats=[InputFormat.PDF, InputFormat.HTML],
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pdf_options)
    }
)

# %%
result = converter.convert("https://www.fh-swf.de/de/studienangebot/studiengaenge/index.php")
# Out:
# list-item has no text: <li class="socialmedia--icon f-size--40 mr--40">
# <a alt="Öffnet sich in neuem Tab oder Fenster" href="https://www.facebook.com/fhsuedwestfalen/" target="_blank" title="facebook">
# <span class="fh-iconfont icon--facebook-f"></span>
# </a>
# </li>
# list-item has no text: <li class="socialmedia--icon f-size--40 mr--40">
# <a alt="Öffnet sich in neuem Tab oder Fenster" href="https://www.instagram.com/fhsuedwestfalen/" target="_blank" title="instagram">
# <span class="fh-iconfont icon--instagram"></span>
# </a>
# </li>
# list-item has no text: <li class="socialmedia--icon f-size--40 mr--40">
# <a alt="Öffnet sich in neuem Tab oder Fenster" href="https://www.youtube.com/user/WebteamFHSWF/about" target="_blank" title="youtube">
# <span class="fh-iconfont icon--youtube"></span>
# </a>
# </li>
# list-item has no text: <li class="socialmedia--icon f-size--40 mr--40">
# ...

# %%
result.document.export_to_html()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <link rel="icon" type="image/png"\n    href="https://ds4sd.github.io/docling/assets/logo.png"/>\n    <meta charset="UTF-8">\n    <title>\n    Powered by Docling\n    </title>\n    <style>\n    html {\n    background-color: LightGray;\n    }\n    body {\n    margin: 0 auto;\n    width:800px;\n    padding: 30px;\n    background-color: White;\n    font-family: Arial, sans-serif;\n    box-shadow: 10px 10px 10px grey;\n    }\n    figure{\n    display: block;\n    width: 100%;\n    margin: 0px;\n    margin-top: 10px;\n    margin-bottom: 10px;\n    }\n    img {\n    display: block;\n    margin: auto;\n    margin-top: 10px;\n    margin-bottom: 10px;\n    max-width: 640px;\n    max-height: 640px;\n    }\n    table {\n    min-width:500px;\n    background-color: White;\n    border-collapse: collapse;\n    cell-padding: 5px;\n    margin: auto;\n    margin-top: 10px;\n    margin-bottom: 10px;\n    }\n    th, td {\n    border: 1px solid black;\n    p
# ...

# %%
result = converter.convert("https://www.fh-swf.de/media/neu_np/hv_2/dateien_sg_2_4/verlaufsplaene_modulhandbuecher_1/hagen/tbw_neu/Modulhandbuch_Winf_FPO_2018_Stand_09.2024.pdf")

# %%
result.document.export_to_markdown()
# Out:
# '## Modulhandbuch\n\nFachhochschule Südwestfalen \uf106\n\nTechnische Betriebswirtschaft Hagen\n\nBachelor of Science\n\nWirtschaftsinformatik\n\nFPO 2018 \uf106\n\nLehrplanvariante: Praxisphase\n\nStand : Winter | 2018\n\nDatum der letzten Veröffentlichung: 23.09.2024\n\n## Begriffserklärung und Hinweise\n\n## Studiengangsvarianten\n\nEin Studiengang kann im Vollzeitstudium, im Teilzeitstudium oder im Verbundstudium angeboten werden. Das Vollzeitstudium ist ein Präsenzstudium, das in der Regel eine Anwesenheit der Studierenden während der Vorlesungszeit an fünf Tagen der Woche erfordert. Die Studierenden der ausbildungs- und berufsbegleitenden Teilzeitvariante besuchen Veranstaltungen während der Vorlesungszeit alle vierzehn Tage samstags. Ein Verbundstudium ist ein Franchise-Model in Kooperation mit anderen Hochschulen. In den Modulbeschreibungen wird zwischen diesen Varianten unterschieden. Entsprechend teilen sich die formalen Angaben, in allgemeine Merkmale, die für alle Variant
# ...
